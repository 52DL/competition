# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_json('../input/train.json')
train['inc_angle'] = pd.to_numeric(train['inc_angle'],errors='coerce')

# %%
icebergs = train[train.is_iceberg==1]
ships = train[train.is_iceberg==0]

# %%
print(icebergs.shape)
print(ships.shape)
# Out:
# (753, 5)
# (851, 5)

# %%
plt.hist(train['inc_angle'],range=[20,60],bins=50)
plt.show()
# Out:
# /Users/afu/anaconda2/envs/ml/lib/python3.6/site-packages/numpy/lib/function_base.py:748: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# /Users/afu/anaconda2/envs/ml/lib/python3.6/site-packages/numpy/lib/function_base.py:749: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %%
i=0

# %%
# Plot band_1
print('i:',i)
print('angle:', icebergs.iloc[i,3])
fig = plt.figure(1,figsize=(15,15))
for j in range(2):
    ax = fig.add_subplot(1,2,j+1)
    arr = np.reshape(np.array(icebergs.iloc[i,j]),(75,75))
    ax.imshow(arr,cmap='inferno')
i+=1
plt.show()
# Out:
# i: 3
# angle: 44.624

# %%
m=0

# %%
# Plot band_1
print('m:',m)
print('angle:', ships.iloc[m,3])
fig = plt.figure(1,figsize=(15,15))
for j in range(2):
    ax = fig.add_subplot(1,2,j+1)
    arr = np.reshape(np.array(ships.iloc[m,j]),(75,75))
    ax.imshow(arr,cmap='inferno')
m+=1
plt.show()
# Out:
# m: 1
# angle: 38.1562
