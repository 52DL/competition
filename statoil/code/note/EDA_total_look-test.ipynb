# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_json('../input/test.json')
train['inc_angle'] = pd.to_numeric(train['inc_angle'],errors='coerce')
train.head()
# Out:
#                                               band_1  \
# 0  [-15.863251, -15.201077, -17.887735, -19.17248...
# 1  [-26.0589694977, -26.0589694977, -26.058969497...
# 2  [-14.1410999298, -15.0642414093, -17.375520706...
# 3  [-12.167478, -13.706167, -16.54837, -13.572674...
# 4  [-23.3745937347, -26.0271816254, -28.121963501...
#
#                                               band_2        id  inc_angle
# 0  [-21.629612, -21.142353, -23.908337, -28.34524...  5941774d  34.966400
# 1  [-25.7542076111, -25.7542076111, -25.754207611...  4023181e  32.615072
# 2  [-14.745639801, -14.5904102325, -14.3626976013...  b20200e4  37.505433
# 3  [-24.32222, -26.375538, -24.096739, -23.8769, ...  e7f018bb  34.473900
# 4  [-25.7223434448, -27.0115776062, -23.149162292...  4371c8c3  43.918874

# %%
train['leakage'] = len(str(train['inc_angle']))

# %%
train.head()
# Out:
#                                               band_1  \
# 0  [-15.863251, -15.201077, -17.887735, -19.17248...
# 1  [-26.0589694977, -26.0589694977, -26.058969497...
# 2  [-14.1410999298, -15.0642414093, -17.375520706...
# 3  [-12.167478, -13.706167, -16.54837, -13.572674...
# 4  [-23.3745937347, -26.0271816254, -28.121963501...
#
#                                               band_2        id  inc_angle  \
# 0  [-21.629612, -21.142353, -23.908337, -28.34524...  5941774d  34.966400
# 1  [-25.7542076111, -25.7542076111, -25.754207611...  4023181e  32.615072
# 2  [-14.745639801, -14.5904102325, -14.3626976013...  b20200e4  37.505433
# 3  [-24.32222, -26.375538, -24.096739, -23.8769, ...  e7f018bb  34.473900
# 4  [-25.7223434448, -27.0115776062, -23.149162292...  4371c8c3  43.918874
#
#    leakage
# 0     1129
# 1     1129
# 2     1129
# 3     1129
# 4     1129

# %%
plt.hist(train['inc_angle'],range=[20,60],bins=50)
plt.show()

# %%
i=0

# %%
# Plot band_1
print('i:',i)
print('angle:', train.iloc[i,3])
fig = plt.figure(1,figsize=(15,15))
for j in range(2):
    ax = fig.add_subplot(1,2,j+1)
    arr = np.reshape(np.array(train.iloc[i,j]),(75,75))
    ax.imshow(arr,cmap='inferno')
i+=1
plt.show()
# Out:
# ('i:', 62)
# ('angle:', 41.433900000000001)

# %%
m=0

# %%
# Plot band_1
print('m:',m)
print('angle:', ships.iloc[m,3])
fig = plt.figure(1,figsize=(15,15))
for j in range(2):
    ax = fig.add_subplot(1,2,j+1)
    arr = np.reshape(np.array(ships.iloc[m,j]),(75,75))
    ax.imshow(arr,cmap='inferno')
m+=1
plt.show()
# Out:
# m: 1
# angle: 38.1562
